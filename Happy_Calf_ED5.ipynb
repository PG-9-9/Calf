# %%
import datetime
import matplotlib
import matplotlib.pyplot as plt
import os
import random
import io
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage
import tensorflow as tf
import pathlib
import itertools
import random

from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

from object_detection.utils import config_util
from object_detection.builders import model_builder
# %matplotlib inline
current_datetime=datetime.datetime.now()
print(f"Calf was last happy on: {current_datetime.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 2023-09-19 18:18:26.222646: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-19 18:18:26.277150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 18:18:28.439664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Calf was last happy on: 2023-09-19 18:18:33

# %%
# !nvidia-smi
print(tf.config.list_physical_devices('GPU'))
# !kill -9 929640
# Optimization:
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
gpu_memory_fraction = 0.8
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Set memory growth for each GPU
        for gpu in gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu,
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=int(gpu_memory_fraction * 1024))]
            )
    except RuntimeError as e:
        print(e)
# Out:
# Tue Sep 19 18:18:33 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3080        On  | 00000000:3E:00.0 Off |                  N/A |
# | 30%   33C    P8              18W / 300W |      2MiB / 10240MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Training the model EfficienDetD1
# !python3 Calf_Detection/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=Calf_Detection/new_app/New_Models/config/efficientdet_d5_coco17_tpu-32.config \
    --model_dir=Calf_Detection/new_app/New_Models/training/efficientdet_d5_coco17_tpu-32 \
    --alsologtostderr

# Export the model EfficienDetD1
pipeline_file = 'Calf_Detection/new_app/New_Models/config/efficientdet_d5_coco17_tpu-32.config'
last_model_path = 'Calf_Detection/new_app/New_Models/training/efficientdet_d5_coco17_tpu-32'
output_directory = "Calf_Detection/new_app/New_Models/finetuned/efficientdet_d5_coco17_tpu-32"
# !python3 Calf_Detection/models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# 2023-09-19 18:18:34.098152: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-19 18:18:34.147279: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 18:18:36.059805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-19 18:18:40.608366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8251 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:3e:00.0, compute capability: 8.6
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0919 18:18:40.609813 139965782147712 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0919 18:18:40.785581 139965782147712 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0919 18:18:40.785744 139965782147712 config_util.py:552] Maybe overwriting use_bfloat16: False
# I0919 18:18:40.797584 139965782147712 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0919 18:18:40.797731 139965782147712 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0919 18:18:40.797780 139965782147712 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0919 18:18:40.802178 139965782147712 efficientnet_model.py:143] round_filter input=32 output=48
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:40.901162 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:40.905160 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:40.911993 139965782147712 efficientnet_model.py:143] round_filter input=32 output=48
# I0919 18:18:40.912137 139965782147712 efficientnet_model.py:143] round_filter input=16 output=24
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:40.945084 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:40.948354 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.032727 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.036007 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.066433 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.069677 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.145614 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.148930 139965782147712 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 18:18:41.275077 139965782147712 efficientnet_model.py:143] round_filter input=16 output=24
# I0919 18:18:41.275229 139965782147712 efficientnet_model.py:143] round_filter input=24 output=40
# I0919 18:18:42.010585 139965782147712 efficientnet_model.py:143] round_filter input=24 output=40
# I0919 18:18:42.010791 139965782147712 efficientnet_model.py:143] round_filter input=40 output=64
# I0919 18:18:42.708965 139965782147712 efficientnet_model.py:143] round_filter input=40 output=64
project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W0919 18:20:26.545022 139949552842496 utils.py:82] Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'stack_6/block_2/expand_bn/gamma:0', 'stack_6/block_2/expand_bn/beta:0', 'stack_6/block_2/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_2/depthwise_bn/gamma:0', 'stack_6/block_2/depthwise_bn/beta:0', 'stack_6/block_2/project_bn/gamma:0', 'stack_6/block_2/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0919 18:20:34.573635 139949552842496 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'stack_6/block_2/expand_bn/gamma:0', 'stack_6/block_2/expand_bn/beta:0', 'stack_6/block_2/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_2/depthwise_bn/gamma:0', 'stack_6/block_2/depthwise_bn/beta:0', 'stack_6/block_2/project_bn/gamma:0', 'stack_6/block_2/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W0919 18:20:42.938205 139949552842496 utils.py:82] Gradients do not exist for variables ['stack_6/block_1/expand_bn/gamma:0', 'stack_6/block_1/expand_bn/beta:0', 'stack_6/block_1/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_1/depthwise_bn/gamma:0', 'stack_6/block_1/depthwise_bn/beta:0', 'stack_6/block_1/project_bn/gamma:0', 'stack_6/block_1/project_bn/beta:0', 'stack_6/block_2/expand_bn/gamma:0', 'stack_6/block_2/expand_bn/beta:0', 'stack_6/block_2/depthwise_conv2d/depthwise_kernel:0', 'stack_6/block_2/depthwise_bn/gamma:0', 'stack_6/block_2/depthwise_bn/beta:0', 'stack_6/block_2/project_bn/gamma:0', 'stack_6/block_2/project_bn/beta:0', 'top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2023-09-19 18:20:55.880508: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientDet-D5/model/stack_0/block_1/drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-09-19 18:21:27.750818: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-09-19 18:21:39.307275: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 288.0KiB (rounded to 294912)requested by op while/body/_1/EfficientDet-D5/bifpn/node_42/6_dn_lvl_6/input_5_up_lvl_7/nearest_neighbor_upsampling_x2/nearest_neighbor_upsampling/ArithmeticOptimizer/ReplacePackWithTileReshape_Tile_h_stack
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-09-19 18:21:39.307467: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-09-19 18:21:39.307498: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 1046, Chunks in use: 1046. 261.5KiB allocated for chunks. 261.5KiB in use in bin. 47.0KiB client-requested in use in bin.
# 2023-09-19 18:21:39.307529: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 225, Chunks in use: 211. 139.2KiB allocated for chunks. 132.2KiB in use in bin. 113.9KiB client-requested in use in bin.
# 2023-09-19 18:21:39.307550: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 1108, Chunks in use: 1104. 1.36MiB allocated for chunks. 1.36MiB in use in bin. 1.23MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307577: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 197, Chunks in use: 197. 552.2KiB allocated for chunks. 552.2KiB in use in bin. 505.2KiB client-requested in use in bin.
# 2023-09-19 18:21:39.307598: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 306, Chunks in use: 306. 1.75MiB allocated for chunks. 1.75MiB in use in bin. 1.68MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307619: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 290, Chunks in use: 290. 2.92MiB allocated for chunks. 2.92MiB in use in bin. 2.81MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307636: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 63, Chunks in use: 63. 1.48MiB allocated for chunks. 1.48MiB in use in bin. 1.41MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307653: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 43, Chunks in use: 42. 1.70MiB allocated for chunks. 1.65MiB in use in bin. 1.57MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307670: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 100, Chunks in use: 99. 8.98MiB allocated for chunks. 8.91MiB in use in bin. 8.81MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307689: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 80, Chunks in use: 80. 14.25MiB allocated for chunks. 14.25MiB in use in bin. 13.49MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307708: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 257, Chunks in use: 257. 83.38MiB allocated for chunks. 83.38MiB in use in bin. 81.45MiB client-requested in use in bin.
# 2023-09-19 18:21:39.307727: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks:
I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f489c02d300 of size 256 next 3459
# 2023-09-19 18:21:39.310038: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f489c02d400 of size 256 next 3462
# ...
# 2023-09-19 18:21:39.370130: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 15728640 totalling 75.00MiB
# 2023-09-19 18:21:39.370138: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 50 Chunks of size 17301504 totalling 825.00MiB
# 2023-09-19 18:21:39.370146: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 21 Chunks of size 18874368 totalling 378.00MiB
# 2023-09-19 18:21:39.370154: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 19641600 totalling 56.19MiB
# 2023-09-19 18:21:39.370162: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 45 Chunks of size 25165824 totalling 1.05GiB
# 2023-09-19 18:21:39.370170: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 28311552 totalling 108.00MiB
# 2023-09-19 18:21:39.370178: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 37748736 totalling 360.00MiB
# 2023-09-19 18:21:39.370186: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 50331648 totalling 480.00MiB
# 2023-09-19 18:21:39.370194: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 38 Chunks of size 62914560 totalling 2.23GiB
# 2023-09-19 18:21:39.370202: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 150994944 totalling 576.00MiB
# 2023-09-19 18:21:39.370210: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 8.06GiB
# 2023-09-19 18:21:39.370218: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 8652128256 memory_limit_: 8652128256 available bytes: 0 curr_region_allocation_bytes_: 17304256512
# 2023-09-19 18:21:39.370233: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      8652128256
# InUse:                      8651993856
# MaxInUse:                   8651993856
# NumAllocs:                       12335
# MaxAllocSize:                201326592
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-09-19 18:21:39.370560: W tensorflow/tsl/framework/bfc_allocator.cc:497] ****************************************************************************************************
# 2023-09-19 18:21:39.370591: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at tile_ops.cc:201 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[4,4,16,288] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-09-19 18:21:39.370642: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 379914805502746697
# 2023-09-19 18:21:39.370655: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 10666172541898199321
# 2023-09-19 18:21:39.370669: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 16507974711696052941
# 2023-09-19 18:21:39.370683: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 13461542495209563295
# 2023-09-19 18:21:39.370696: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 12220484402996898419
# 2023-09-19 18:21:39.370710: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 10743518463350508329
# 2023-09-19 18:21:39.370722: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 105314691895586435
# 2023-09-19 18:21:39.370737: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 16657483730203996288
# 2023-09-19 18:21:39.370749: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 8164072807331488338
# 2023-09-19 18:21:39.370761: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 10424629976213783336
# 2023-09-19 18:21:39.370778: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 9087703106884559886
# 2023-09-19 18:21:39.370788: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 3702801571282130414
# 2023-09-19 18:21:39.370800: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 11042821632597530658
# 2023-09-19 18:21:39.370811: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 14300201734325614924
# 2023-09-19 18:21:39.370843: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 9325992684008644104
# Traceback (most recent call last):
#   File "/home/woody/iwfa/iwfa030h/Calf_Detection/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/home/woody/iwfa/iwfa030h/Calf_Detection/models/research/object_detection/model_main_tf2.py", line 105, in main
#     model_lib_v2.train_loop(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/object_detection/model_lib_v2.py", line 685, in train_loop
#     losses_dict = _dist_train_step(train_input_iter)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: Graph execution error:
#
# 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[4,4,16,288] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node while/body/_1/EfficientDet-D5/bifpn/node_42/6_dn_lvl_6/input_5_up_lvl_7/nearest_neighbor_upsampling_x2/nearest_neighbor_upsampling/ArithmeticOptimizer/ReplacePackWithTileReshape_Tile_h_stack}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[train_input_images/write_summary/summary_cond/then/_2457/train_input_images/write_summary/ReadVariableOp/_34]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[4,4,16,288] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node while/body/_1/EfficientDet-D5/bifpn/node_42/6_dn_lvl_6/input_5_up_lvl_7/nearest_neighbor_upsampling_x2/nearest_neighbor_upsampling/ArithmeticOptimizer/ReplacePackWithTileReshape_Tile_h_stack}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference__dist_train_step_179032]
# 2023-09-19 18:21:46.936923: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-19 18:21:46.992429: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 18:21:49.218703: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-19 18:21:54.775698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8251 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:3e:00.0, compute capability: 8.6
# I0919 18:21:54.938958 139794040697472 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0919 18:21:54.939136 139794040697472 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0919 18:21:54.939187 139794040697472 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0919 18:21:54.943503 139794040697472 efficientnet_model.py:143] round_filter input=32 output=48
# I0919 18:21:55.005845 139794040697472 efficientnet_model.py:143] round_filter input=32 output=48
# I0919 18:21:55.005986 139794040697472 efficientnet_model.py:143] round_filter input=16 output=24
# I0919 18:21:55.278736 139794040697472 efficientnet_model.py:143] round_filter input=16 output=24
# I0919 18:21:55.278878 139794040697472 efficientnet_model.py:143] round_filter input=24 output=40
# I0919 18:21:55.785693 139794040697472 efficientnet_model.py:143] round_filter input=24 output=40
# I0919 18:21:55.785830 139794040697472 efficientnet_model.py:143] round_filter input=40 output=64
# I0919 18:21:56.298026 139794040697472 efficientnet_model.py:143] round_filter input=40 output=64
# I0919 18:21:56.298170 139794040697472 efficientnet_model.py:143] round_filter input=80 output=128
# I0919 18:21:56.990224 139794040697472 efficientnet_model.py:143] round_filter input=80 output=128
# I0919 18:21:56.990405 139794040697472 efficientnet_model.py:143] round_filter input=112 output=176
# I0919 18:21:57.649434 139794040697472 efficientnet_model.py:143] round_filter input=112 output=176
# I0919 18:21:57.649561 139794040697472 efficientnet_model.py:143] round_filter input=192 output=304
# I0919 18:21:58.742339 139794040697472 efficientnet_model.py:143] round_filter input=192 output=304
# I0919 18:21:58.742484 139794040697472 efficientnet_model.py:143] round_filter input=320 output=512
# I0919 18:21:59.059426 139794040697472 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0919 18:21:59.114913 139794040697472 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0919 18:22:03.182878 139794040697472 deprecation.py:641] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0919 18:22:11.288663 139794040697472 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I0919 18:22:23.517740 139794040697472 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I0919 18:22:28.556812 139794040697472 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_classpredictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0919 18:22:33.357584 139794040697472 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f23202e9490>, because it is not built.
# W0919 18:22:35.754729 139794040697472 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f23202e9490>, because it is not built.
# I0919 18:23:28.416891 139794040697472 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 848). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Calf_Detection/new_app/New_Models/finetuned/efficientdet_d5_coco17_tpu-32/saved_model/assets
# I0919 18:24:14.859507 139794040697472 builder_impl.py:804] Assets written to: Calf_Detection/new_app/New_Models/finetuned/efficientdet_d5_coco17_tpu-32/saved_model/assets
# I0919 18:24:16.295952 139794040697472 fingerprinting_utils.py:48] Writing fingerprint to Calf_Detection/new_app/New_Models/finetuned/efficientdet_d5_coco17_tpu-32/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to Calf_Detection/new_app/New_Models/finetuned/efficientdet_d5_coco17_tpu-32/pipeline.config
# I0919 18:24:18.826839 139794040697472 config_util.py:253] Writing pipeline config file to Calf_Detection/new_app/New_Models/finetuned/efficientdet_d5_coco17_tpu-32/pipeline.config

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.
  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.
  Args:
    path: a file path.
  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.8)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

filenames = list(pathlib.Path('Calf_Detection/new_app/New_Models/training/efficientdet_d5_coco17_tpu-32').glob('*.index'))

filenames.sort()

# recover our saved model
model_dir = 'Calf_Detection/new_app/New_Models/training/efficientdet_d5_coco17_tpu-32'
# Adding the last checkpoint
pipeline_file = 'Calf_Detection/new_app/New_Models/config/efficientdet_d5_coco17_tpu-32.config'
configs = config_util.get_configs_from_pipeline_file(pipeline_file)
model_config = configs['model']
detection_model = model_builder.build(
      model_config=model_config, is_training=False)

print(detection_model)
# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(str(filenames[-1]).replace('.index',''))).expect_partial()
print(os.path.join(str(filenames[-1]).replace('.index','')))

def get_model_detection_function(model):
  """Get a tf.function for detection."""

  @tf.function
  def detect_fn(image):
    """Detect objects in image."""

    image, shapes = model.preprocess(image)
    prediction_dict = model.predict(image, shapes)
    detections = model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

  return detect_fn

detect_fn = get_model_detection_function(detection_model)    
# map labels for inference decoding
label_map_path = configs['eval_input_config'].label_map_path
label_map = label_map_util.load_labelmap(label_map_path)
categories = label_map_util.convert_label_map_to_categories(
    label_map,
    max_num_classes=label_map_util.get_max_label_map_index(label_map),
    use_display_name=True)
category_index = label_map_util.create_category_index(categories)
label_map_dict = label_map_util.get_label_map_dict(label_map, use_display_name=True)
#run detector on test image
#it takes a little longer on the first run and then runs at normal speed. 

TEST_IMAGE_PATHS = glob.glob('Calf_Detection/new_app/test/2019-06-29_090001.jpg')
image_path = random.choice(TEST_IMAGE_PATHS)
image_np = load_image_into_numpy_array(image_path)

input_tensor = tf.convert_to_tensor(
    np.expand_dims(image_np, 0), dtype=tf.float32)
detections, predictions_dict, shapes = detect_fn(input_tensor)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections,
      detections['detection_boxes'][0].numpy(),
      (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
      detections['detection_scores'][0].numpy(),
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=1,
      min_score_thresh=.1,
      agnostic_mode=False,
)

plt.figure(figsize=(12,16))
plt.imshow(image_np_with_detections)
plt.axis("off")
plt.show()
# Out:
# 2023-09-19 18:24:23.170117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 819 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:3e:00.0, compute capability: 8.6
# <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7ffa106a9ee0>
# Calf_Detection/new_app/New_Models/training/efficientdet_d5_coco17_tpu-32/ckpt-1
# 2023-09-19 18:24:57.449564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2023-09-19 18:24:57.534244: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023
deprecation.py:364] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32
# I0919 18:25:16.680830 140050281407104 checkpoint_utils.py:168] Waiting for new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32
# INFO:tensorflow:Found new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32/ckpt-2
# I0919 18:25:16.682593 140050281407104 checkpoint_utils.py:177] Found new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32/ckpt-2
# /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0919 18:25:25.190924 140050281407104 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0919 18:25:38.538704 140050281407104 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2023-09-19 18:25:44.150878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2023-09-19 18:25:44.242968: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-09-19 18:25:44.606729: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# WARNING:tensorflow:From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0919 18:25:44.796859 140050281407104 deprecation.py:364] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0919 18:25:44.835612 140050281407104 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0919 18:25:45.007683 140050281407104 deprecation.py:364] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0919 18:25:54.568749 140050281407104 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Performing evaluation on 170 images.
# I0919 18:25:59.117335 140050281407104 coco_evaluation.py:293] Performing evaluation on 170 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0919 18:25:59.120304 140050281407104 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0919 18:25:59.132460 140050281407104 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.60s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.365
# INFO:tensorflow:Eval metrics at step 1000
# I0919 18:25:59.928126 140050281407104 model_lib_v2.py:1015] Eval metrics at step 1000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.110828
# I0919 18:25:59.948687 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.110828
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.351475
# I0919 18:25:59.950990 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.351475
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.026925
# I0919 18:25:59.953741 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.026925
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0919 18:25:59.955606 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.105738
# I0919 18:25:59.957297 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.105738
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.124184
# I0919 18:25:59.958501 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.124184
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.188000
# I0919 18:25:59.959611 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.188000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.345368
# I0919 18:25:59.960653 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.345368
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.374977
# I0919 18:25:59.961672 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.374977
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0919 18:25:59.962587 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.407761
# I0919 18:25:59.963572 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.407761
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.365476
# I0919 18:25:59.964595 140050281407104 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.365476
# INFO:tensorflow:	+ Loss/localization_loss: 0.012652
# I0919 18:25:59.965448 140050281407104 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.012652
# INFO:tensorflow:	+ Loss/classification_loss: 5.281000
# I0919 18:25:59.966281 140050281407104 model_lib_v2.py:1018] 	+ Loss/classification_loss: 5.281000
# INFO:tensorflow:	+ Loss/regularization_loss: 0.031188
# I0919 18:25:59.967068 140050281407104 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.031188
# INFO:tensorflow:	+ Loss/total_loss: 5.324840
# I0919 18:25:59.967847 140050281407104 model_lib_v2.py:1018] 	+ Loss/total_loss: 5.324840
# INFO:tensorflow:Waiting for new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32
# I0919 18:30:16.757224 140050281407104 checkpoint_utils.py:168] Waiting for new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32
# ^C
# Traceback (most recent call last):
#   File "/home/woody/iwfa/iwfa030h/Calf_Detection/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/home/woody/iwfa/iwfa030h/Calf_Detection/models/research/object_detection/model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/object_detection/model_lib_v2.py", line 1135, in eval_continuously
#     for latest_checkpoint in tf.train.checkpoints_iterator(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/training/checkpoint_utils.py", line 226, in checkpoints_iterator
#     new_checkpoint_path = wait_for_new_checkpoint(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/training/checkpoint_utils.py", line 175, in wait_for_new_checkpoint
#     time.sleep(seconds_to_sleep)
# KeyboardInterrupt
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
