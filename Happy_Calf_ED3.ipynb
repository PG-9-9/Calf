# %%
import datetime
import matplotlib
import matplotlib.pyplot as plt
import os
import random
import io
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage
import tensorflow as tf
import pathlib
import itertools
import random

from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

from object_detection.utils import config_util
from object_detection.builders import model_builder
# %matplotlib inline
current_datetime=datetime.datetime.now()
print(f"Calf was last happy on: {current_datetime.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Calf was last happy on: 2023-09-19 17:01:38

# %%
# !nvidia-smi
print(tf.config.list_physical_devices('GPU'))
# Optimization:
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
gpu_memory_fraction = 0.8
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Set memory growth for each GPU
        for gpu in gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu,
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=int(gpu_memory_fraction * 1024))]
            )
    except RuntimeError as e:
        print(e)
# Out:
# Tue Sep 19 17:01:38 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3080        On  | 00000000:3E:00.0 Off |                  N/A |
# | 30%   33C    P8              18W / 300W |      5MiB / 10240MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Training the model EfficienDetD1
# !python3 Calf_Detection/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=Calf_Detection/new_app/New_Models/config/efficientdet_d3_coco17_tpu-32.config \
    --model_dir=Calf_Detection/new_app/New_Models/training/efficientdet_d3_coco17_tpu-32 \
    --alsologtostderr

# Export the model EfficienDetD1
pipeline_file = 'Calf_Detection/new_app/New_Models/config/efficientdet_d3_coco17_tpu-32.config'
last_model_path = 'Calf_Detection/new_app/New_Models/training/efficientdet_d3_coco17_tpu-32'
output_directory = "Calf_Detection/new_app/New_Models/finetuned/efficientdet_d3_coco17_tpu-32"
# !python3 Calf_Detection/models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# 2023-09-19 17:01:39.345843: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-19 17:01:39.395830: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 17:01:41.320371: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-19 17:01:46.471989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8251 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:3e:00.0, compute capability: 8.6
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0919 17:01:46.473308 139746201629312 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0919 17:01:46.636737 139746201629312 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0919 17:01:46.636907 139746201629312 config_util.py:552] Maybe overwriting use_bfloat16: False
# I0919 17:01:46.648387 139746201629312 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0919 17:01:46.648539 139746201629312 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0919 17:01:46.648594 139746201629312 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0919 17:01:46.653422 139746201629312 efficientnet_model.py:143] round_filter input=32 output=40
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.717290 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.721141 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.727927 139746201629312 efficientnet_model.py:143] round_filter input=32 output=40
# I0919 17:01:46.728065 139746201629312 efficientnet_model.py:143] round_filter input=16 output=24
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.759857 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.763157 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.841214 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.844351 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.881005 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.884400 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.964168 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.967416 139746201629312 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0919 17:01:46.979246 139746201629312 efficientnet_model.py:143] round_filter input=16 output=24
# I0919 17:01:46.979382 139746201629312 efficientnet_model.py:143] round_filter input=24 output=32
# I0919 17:01:47.418704 139746201629312 efficientnet_model.py:143] round_filter input=24 output=32
# I0919 17:01:47.418853 139746201629312 efficientnet_model.py:143] round_filter input=40 output=48
# I0919 17:01:47.857009 139746201629312 efficientnet_model.py:143] round_filter input=40 output=48
# I0919 17:01:47.857152 139746201629312 efficientnet_model.py:143] round_filter input=80 output=96
# I0919 17:01:48.507813 139746201629312 efficientnet_model.py:143] round_filter input=80 output=96
#  'Loss/localization_loss': 0.016176805,
#  'Loss/regularization_loss': 0.03885493,
#  'Loss/total_loss': 0.72926193,
#  'learning_rate': 0.010480001}
# I0919 17:05:25.695238 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.67423016,
#  'Loss/localization_loss': 0.016176805,
#  'Loss/regularization_loss': 0.03885493,
#  'Loss/total_loss': 0.72926193,
#  'learning_rate': 0.010480001}
# INFO:tensorflow:Step 400 per-step time 0.282s
# I0919 17:05:53.913606 139746201629312 model_lib_v2.py:705] Step 400 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.67940485,
#  'Loss/localization_loss': 0.029729115,
#  'Loss/regularization_loss': 0.03902752,
#  'Loss/total_loss': 0.7481615,
#  'learning_rate': 0.0136400005}
# I0919 17:05:53.913959 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.67940485,
#  'Loss/localization_loss': 0.029729115,
#  'Loss/regularization_loss': 0.03902752,
#  'Loss/total_loss': 0.7481615,
#  'learning_rate': 0.0136400005}
# INFO:tensorflow:Step 500 per-step time 0.282s
# I0919 17:06:22.140697 139746201629312 model_lib_v2.py:705] Step 500 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.43207225,
#  'Loss/localization_loss': 0.008161869,
#  'Loss/regularization_loss': 0.0391613,
#  'Loss/total_loss': 0.47939542,
#  'learning_rate': 0.016800001}
# I0919 17:06:22.140995 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.43207225,
#  'Loss/localization_loss': 0.008161869,
#  'Loss/regularization_loss': 0.0391613,
#  'Loss/total_loss': 0.47939542,
#  'learning_rate': 0.016800001}
# INFO:tensorflow:Step 600 per-step time 0.282s
# I0919 17:06:50.328244 139746201629312 model_lib_v2.py:705] Step 600 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.41615415,
#  'Loss/localization_loss': 0.02177722,
#  'Loss/regularization_loss': 0.039300766,
#  'Loss/total_loss': 0.47723213,
#  'learning_rate': 0.019960001}
# I0919 17:06:50.328732 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.41615415,
#  'Loss/localization_loss': 0.02177722,
#  'Loss/regularization_loss': 0.039300766,
#  'Loss/total_loss': 0.47723213,
#  'learning_rate': 0.019960001}
# INFO:tensorflow:Step 700 per-step time 0.282s
# I0919 17:07:18.553117 139746201629312 model_lib_v2.py:705] Step 700 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.8814214,
#  'Loss/localization_loss': 0.026133554,
#  'Loss/regularization_loss': 0.03955684,
#  'Loss/total_loss': 0.9471118,
#  'learning_rate': 0.023120001}
# I0919 17:07:18.553446 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.8814214,
#  'Loss/localization_loss': 0.026133554,
#  'Loss/regularization_loss': 0.03955684,
#  'Loss/total_loss': 0.9471118,
#  'learning_rate': 0.023120001}
# INFO:tensorflow:Step 800 per-step time 0.282s
# I0919 17:07:46.764008 139746201629312 model_lib_v2.py:705] Step 800 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.9260199,
#  'Loss/localization_loss': 0.016697602,
#  'Loss/regularization_loss': 0.04006783,
#  'Loss/total_loss': 0.98278534,
#  'learning_rate': 0.02628}
# I0919 17:07:46.764285 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.9260199,
#  'Loss/localization_loss': 0.016697602,
#  'Loss/regularization_loss': 0.04006783,
#  'Loss/total_loss': 0.98278534,
#  'learning_rate': 0.02628}
# INFO:tensorflow:Step 900 per-step time 0.283s
# I0919 17:08:15.024502 139746201629312 model_lib_v2.py:705] Step 900 per-step time 0.283s
# INFO:tensorflow:{'Loss/classification_loss': 0.76183486,
#  'Loss/localization_loss': 0.013713516,
#  'Loss/regularization_loss': 0.040280256,
#  'Loss/total_loss': 0.8158287,
#  'learning_rate': 0.02944}
# I0919 17:08:15.024816 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.76183486,
#  'Loss/localization_loss': 0.013713516,
#  'Loss/regularization_loss': 0.040280256,
#  'Loss/total_loss': 0.8158287,
#  'learning_rate': 0.02944}
# INFO:tensorflow:Step 1000 per-step time 0.282s
# I0919 17:08:43.258030 139746201629312 model_lib_v2.py:705] Step 1000 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.8022514,
#  'Loss/localization_loss': 0.018754369,
#  'Loss/regularization_loss': 0.040575035,
#  'Loss/total_loss': 0.8615808,
#  'learning_rate': 0.0326}
# I0919 17:08:43.258797 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.8022514,
#  'Loss/localization_loss': 0.018754369,
#  'Loss/regularization_loss': 0.040575035,
#  'Loss/total_loss': 0.8615808,
#  'learning_rate': 0.0326}
# INFO:tensorflow:Step 1100 per-step time 0.317s
# I0919 17:09:14.940191 139746201629312 model_lib_v2.py:705] Step 1100 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.45781022,
#  'Loss/localization_loss': 0.017225148,
#  'Loss/regularization_loss': 0.040836606,
#  'Loss/total_loss': 0.515872,
#  'learning_rate': 0.03576}
# I0919 17:09:14.940500 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.45781022,
#  'Loss/localization_loss': 0.017225148,
#  'Loss/regularization_loss': 0.040836606,
#  'Loss/total_loss': 0.515872,
#  'learning_rate': 0.03576}
# INFO:tensorflow:Step 1200 per-step time 0.282s
# I0919 17:09:43.180088 139746201629312 model_lib_v2.py:705] Step 1200 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.3691447,
#  'Loss/localization_loss': 0.010673781,
#  'Loss/regularization_loss': 0.041128583,
#  'Loss/total_loss': 0.42094707,
#  'learning_rate': 0.03892}
# I0919 17:09:43.180394 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.3691447,
#  'Loss/localization_loss': 0.010673781,
#  'Loss/regularization_loss': 0.041128583,
#  'Loss/total_loss': 0.42094707,
#  'learning_rate': 0.03892}
# INFO:tensorflow:Step 1300 per-step time 0.282s
# I0919 17:10:11.422251 139746201629312 model_lib_v2.py:705] Step 1300 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.7465644,
#  'Loss/localization_loss': 0.01502526,
#  'Loss/regularization_loss': 0.041426346,
#  'Loss/total_loss': 0.803016,
#  'learning_rate': 0.04208}
# I0919 17:10:11.422528 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.7465644,
#  'Loss/localization_loss': 0.01502526,
#  'Loss/regularization_loss': 0.041426346,
#  'Loss/total_loss': 0.803016,
#  'learning_rate': 0.04208}
# INFO:tensorflow:Step 1400 per-step time 0.283s
# I0919 17:10:39.673249 139746201629312 model_lib_v2.py:705] Step 1400 per-step time 0.283s
# INFO:tensorflow:{'Loss/classification_loss': 0.41312796,
#  'Loss/localization_loss': 0.012467382,
#  'Loss/regularization_loss': 0.041799113,
#  'Loss/total_loss': 0.46739447,
#  'learning_rate': 0.04524}
# I0919 17:10:39.673745 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.41312796,
#  'Loss/localization_loss': 0.012467382,
#  'Loss/regularization_loss': 0.041799113,
#  'Loss/total_loss': 0.46739447,
#  'learning_rate': 0.04524}
# INFO:tensorflow:Step 1500 per-step time 0.283s
# I0919 17:11:07.935317 139746201629312 model_lib_v2.py:705] Step 1500 per-step time 0.283s
# INFO:tensorflow:{'Loss/classification_loss': 0.7957883,
#  'Loss/localization_loss': 0.010190947,
#  'Loss/regularization_loss': 0.042514905,
#  'Loss/total_loss': 0.8484942,
#  'learning_rate': 0.0484}
# I0919 17:11:07.935765 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.7957883,
#  'Loss/localization_loss': 0.010190947,
#  'Loss/regularization_loss': 0.042514905,
#  'Loss/total_loss': 0.8484942,
#  'learning_rate': 0.0484}
# INFO:tensorflow:Step 1600 per-step time 0.282s
# I0919 17:11:36.154358 139746201629312 model_lib_v2.py:705] Step 1600 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.81951195,
#  'Loss/localization_loss': 0.015352061,
#  'Loss/regularization_loss': 0.045330007,
#  'Loss/total_loss': 0.880194,
#  'learning_rate': 0.05156}
# I0919 17:11:36.154678 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.81951195,
#  'Loss/localization_loss': 0.015352061,
#  'Loss/regularization_loss': 0.045330007,
#  'Loss/total_loss': 0.880194,
#  'learning_rate': 0.05156}
# INFO:tensorflow:Step 1700 per-step time 0.282s
# I0919 17:12:04.382293 139746201629312 model_lib_v2.py:705] Step 1700 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.9139236,
#  'Loss/localization_loss': 0.021355996,
#  'Loss/regularization_loss': 0.045886487,
#  'Loss/total_loss': 0.9811661,
#  'learning_rate': 0.05472}
# I0919 17:12:04.382560 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.9139236,
#  'Loss/localization_loss': 0.021355996,
#  'Loss/regularization_loss': 0.045886487,
#  'Loss/total_loss': 0.9811661,
#  'learning_rate': 0.05472}
# INFO:tensorflow:Step 1800 per-step time 0.282s
# I0919 17:12:32.627104 139746201629312 model_lib_v2.py:705] Step 1800 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.5763462,
#  'Loss/localization_loss': 0.010673571,
#  'Loss/regularization_loss': 0.04619019,
#  'Loss/total_loss': 0.63321,
#  'learning_rate': 0.05788}
# I0919 17:12:32.627500 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.5763462,
#  'Loss/localization_loss': 0.010673571,
#  'Loss/regularization_loss': 0.04619019,
#  'Loss/total_loss': 0.63321,
#  'learning_rate': 0.05788}
# INFO:tensorflow:Step 1900 per-step time 0.282s
# I0919 17:13:00.839409 139746201629312 model_lib_v2.py:705] Step 1900 per-step time 0.282s
# INFO:tensorflow:{'Loss/classification_loss': 0.7246491,
#  'Loss/localization_loss': 0.013008859,
#  'Loss/regularization_loss': 0.04646129,
#  'Loss/total_loss': 0.7841192,
#  'learning_rate': 0.06104}
# I0919 17:13:00.839952 139746201629312 model_lib_v2.py:708] {'Loss/classification_loss': 0.7246491,
#  'Loss/localization_loss': 0.013008859,
#  'Loss/regularization_loss': 0.04646129,
#  'Loss/total_loss': 0.7841192,
#  'learning_rate': 0.06104}
# 2023-09-19 17:13:07.217442: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-19 17:13:07.267771: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 17:13:09.934695: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-19 17:13:16.535808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8251 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:3e:00.0, compute capability: 8.6
# I0919 17:13:16.695703 140591328686720 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0919 17:13:16.695889 140591328686720 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0919 17:13:16.695941 140591328686720 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0919 17:13:16.700502 140591328686720 efficientnet_model.py:143] round_filter input=32 output=40
# I0919 17:13:16.770908 140591328686720 efficientnet_model.py:143] round_filter input=32 output=40
# I0919 17:13:16.771089 140591328686720 efficientnet_model.py:143] round_filter input=16 output=24
# I0919 17:13:16.964811 140591328686720 efficientnet_model.py:143] round_filter input=16 output=24
# I0919 17:13:16.964977 140591328686720 efficientnet_model.py:143] round_filter input=24 output=32
# I0919 17:13:17.299520 140591328686720 efficientnet_model.py:143] round_filter input=24 output=32
# I0919 17:13:17.299662 140591328686720 efficientnet_model.py:143] round_filter input=40 output=48
# I0919 17:13:17.596648 140591328686720 efficientnet_model.py:143] round_filter input=40 output=48
# I0919 17:13:17.596779 140591328686720 efficientnet_model.py:143] round_filter input=80 output=96
# I0919 17:13:18.114546 140591328686720 efficientnet_model.py:143] round_filter input=80 output=96
# I0919 17:13:18.114777 140591328686720 efficientnet_model.py:143] round_filter input=112 output=136
# I0919 17:13:18.603949 140591328686720 efficientnet_model.py:143] round_filter input=112 output=136
# I0919 17:13:18.604111 140591328686720 efficientnet_model.py:143] round_filter input=192 output=232
# I0919 17:13:19.193423 140591328686720 efficientnet_model.py:143] round_filter input=192 output=232
# I0919 17:13:19.193573 140591328686720 efficientnet_model.py:143] round_filter input=320 output=384
# I0919 17:13:19.418580 140591328686720 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0919 17:13:19.479362 140591328686720 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0919 17:13:21.788553 140591328686720 deprecation.py:641] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0919 17:13:28.920279 140591328686720 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I0919 17:13:40.953934 140591328686720 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I0919 17:13:45.365547 140591328686720 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_classpredictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0919 17:13:48.979520 140591328686720 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fdcb4655ee0>, because it is not built.
# W0919 17:13:51.496204 140591328686720 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fdcb4655ee0>, because it is not built.
# I0919 17:14:32.513061 140591328686720 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 720). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Calf_Detection/new_app/New_Models/finetuned/efficientdet_d3_coco17_tpu-32/saved_model/assets
# I0919 17:15:08.800466 140591328686720 builder_impl.py:804] Assets written to: Calf_Detection/new_app/New_Models/finetuned/efficientdet_d3_coco17_tpu-32/saved_model/assets
# I0919 17:15:09.973208 140591328686720 fingerprinting_utils.py:48] Writing fingerprint to Calf_Detection/new_app/New_Models/finetuned/efficientdet_d3_coco17_tpu-32/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to Calf_Detection/new_app/New_Models/finetuned/efficientdet_d3_coco17_tpu-32/pipeline.config
# I0919 17:15:11.990792 140591328686720 config_util.py:253] Writing pipeline config file to Calf_Detection/new_app/New_Models/finetuned/efficientdet_d3_coco17_tpu-32/pipeline.config

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.
  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.
  Args:
    path: a file path.
  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.8)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

filenames = list(pathlib.Path('Calf_Detection/new_app/New_Models/training/efficientdet_d3_coco17_tpu-32').glob('*.index'))

filenames.sort()

# recover our saved model
model_dir = 'Calf_Detection/new_app/New_Models/training/efficientdet_d3_coco17_tpu-32'
# Adding the last checkpoint
pipeline_file = 'Calf_Detection/new_app/New_Models/config/efficientdet_d3_coco17_tpu-32.config'
configs = config_util.get_configs_from_pipeline_file(pipeline_file)
model_config = configs['model']
detection_model = model_builder.build(
      model_config=model_config, is_training=False)

print(detection_model)
# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(str(filenames[-1]).replace('.index',''))).expect_partial()
print(os.path.join(str(filenames[-1]).replace('.index','')))

def get_model_detection_function(model):
  """Get a tf.function for detection."""

  @tf.function
  def detect_fn(image):
    """Detect objects in image."""

    image, shapes = model.preprocess(image)
    prediction_dict = model.predict(image, shapes)
    detections = model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

  return detect_fn

detect_fn = get_model_detection_function(detection_model)    
# map labels for inference decoding
label_map_path = configs['eval_input_config'].label_map_path
label_map = label_map_util.load_labelmap(label_map_path)
categories = label_map_util.convert_label_map_to_categories(
    label_map,
    max_num_classes=label_map_util.get_max_label_map_index(label_map),
    use_display_name=True)
category_index = label_map_util.create_category_index(categories)
label_map_dict = label_map_util.get_label_map_dict(label_map, use_display_name=True)
#run detector on test image
#it takes a little longer on the first run and then runs at normal speed. 

TEST_IMAGE_PATHS = glob.glob('Calf_Detection/new_app/test/2019-06-29_090001.jpg')
image_path = random.choice(TEST_IMAGE_PATHS)
image_np = load_image_into_numpy_array(image_path)

input_tensor = tf.convert_to_tensor(
    np.expand_dims(image_np, 0), dtype=tf.float32)
detections, predictions_dict, shapes = detect_fn(input_tensor)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections,
      detections['detection_boxes'][0].numpy(),
      (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
      detections['detection_scores'][0].numpy(),
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=1,
      min_score_thresh=.1,
      agnostic_mode=False,
)

plt.figure(figsize=(12,16))
plt.imshow(image_np_with_detections)
plt.axis("off")
plt.show()
# Out:
# 2023-09-19 17:15:15.814877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 819 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:3e:00.0, compute capability: 8.6
# <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fad04773520>
# Calf_Detection/new_app/New_Models/training/efficientdet_d3_coco17_tpu-32/ckpt-2
# 2023-09-19 17:15:45.473272: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 
home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0919 17:16:16.410276 140277672829568 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0919 17:16:30.695481 140277672829568 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2023-09-19 17:16:36.745598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2023-09-19 17:16:36.838970: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-09-19 17:16:37.199267: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# WARNING:tensorflow:From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0919 17:16:37.407129 140277672829568 deprecation.py:364] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0919 17:16:37.447283 140277672829568 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0919 17:16:37.629104 140277672829568 deprecation.py:364] From /home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0919 17:16:47.322340 140277672829568 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Performing evaluation on 170 images.
# I0919 17:16:51.929296 140277672829568 coco_evaluation.py:293] Performing evaluation on 170 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0919 17:16:51.930415 140277672829568 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0919 17:16:51.940819 140277672829568 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.61s).
# Accumulating evaluation results...
# DONE (t=0.20s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.365
# INFO:tensorflow:Eval metrics at step 1000
# I0919 17:16:52.782223 140277672829568 model_lib_v2.py:1015] Eval metrics at step 1000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.110828
# I0919 17:16:52.804478 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.110828
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.351475
# I0919 17:16:52.806474 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.351475
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.026925
# I0919 17:16:52.807976 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.026925
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0919 17:16:52.809344 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.105738
# I0919 17:16:52.810626 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.105738
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.124184
# I0919 17:16:52.811907 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.124184
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.188000
# I0919 17:16:52.813048 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.188000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.345368
# I0919 17:16:52.814153 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.345368
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.374977
# I0919 17:16:52.815240 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.374977
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0919 17:16:52.816195 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.407761
# I0919 17:16:52.817283 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.407761
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.365476
# I0919 17:16:52.818416 140277672829568 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.365476
# INFO:tensorflow:	+ Loss/localization_loss: 0.012652
# I0919 17:16:52.819247 140277672829568 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.012652
# INFO:tensorflow:	+ Loss/classification_loss: 5.281000
# I0919 17:16:52.820089 140277672829568 model_lib_v2.py:1018] 	+ Loss/classification_loss: 5.281000
# INFO:tensorflow:	+ Loss/regularization_loss: 0.031188
# I0919 17:16:52.820899 140277672829568 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.031188
# INFO:tensorflow:	+ Loss/total_loss: 5.324840
# I0919 17:16:52.821700 140277672829568 model_lib_v2.py:1018] 	+ Loss/total_loss: 5.324840
# INFO:tensorflow:Waiting for new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32
# I0919 17:21:07.129047 140277672829568 checkpoint_utils.py:168] Waiting for new checkpoint at Calf_Detection/new_app/New_Models/training/efficientdet_d1_coco17_tpu-32
# ^C
# Traceback (most recent call last):
#   File "/home/woody/iwfa/iwfa030h/Calf_Detection/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/home/woody/iwfa/iwfa030h/Calf_Detection/models/research/object_detection/model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/object_detection/model_lib_v2.py", line 1135, in eval_continuously
#     for latest_checkpoint in tf.train.checkpoints_iterator(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/training/checkpoint_utils.py", line 226, in checkpoints_iterator
#     new_checkpoint_path = wait_for_new_checkpoint(
#   File "/home/hpc/iwfa/iwfa030h/miniconda3/envs/tf_od/lib/python3.9/site-packages/tensorflow/python/training/checkpoint_utils.py", line 175, in wait_for_new_checkpoint
#     time.sleep(seconds_to_sleep)
# KeyboardInterrupt
