# %%
import os
import librosa
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, TimeDistributed, RepeatVector
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2023-12-18 10:25:52.252163: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-18 10:25:52.274646: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 10:25:52.427036: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 10:25:52.428094: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 10:25:53.031229: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
directory = 'Audio_Work/birth_inference_minutes_wav/output_2023-11-04_06-31-01'

# %%
# Choosing the sample rate for the audio files 
#TODO:
# 1. Automate the sampling rate selection.

def analyze_sampling_rates(directory):
    sampling_rates = []
    for file in os.listdir(directory):
        if file.endswith('.wav'):
            path = os.path.join(directory, file)
            _, sr = librosa.load(path, sr=None, duration=5)  # Load only a part  of the file.
            sampling_rates.append(sr)
    return sampling_rates

def choose_optimal_sampling_rate(sampling_rates):
    # Choosing the most common sampling rate 
    optimal_sr = max(set(sampling_rates), key=sampling_rates.count)
    return optimal_sr

sampling_rates = analyze_sampling_rates(directory)
optimal_sr = choose_optimal_sampling_rate(sampling_rates) # (44100) This will be constant for all the files

print("Sampling Rates:", sampling_rates)
print("Optimal Sampling Rate:", optimal_sr)
# Out:
# Sampling Rates: [44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100, 44100]
# Optimal Sampling Rate: 44100

# %%
# Choosing the optimal_duration for the audio files 
# Should ideally be 1 minute ( but its better to check)
# TODO:
#       1.Consider  np.median(durations) for a median duration

def get_optimal_duration(directory, sr=22050):
    durations = []
    for file in os.listdir(directory):
        if file.endswith('.wav'):
            path = os.path.join(directory, file)
            data, _ = librosa.load(path, sr=sr)
            durations.append(len(data) / sr)
    return min(durations)

# %%
def load_and_preprocess_audio(directory, sr):
    duration = get_optimal_duration(directory, sr)
    max_length = int(sr * duration)
    audio_data = []
    for file in os.listdir(directory):
        if file.endswith('.wav'):
            path = os.path.join(directory, file)
            data, _ = librosa.load(path, sr=sr, duration=duration)
            if len(data) > max_length:
                data = data[:max_length]
            else:
                padding = max_length - len(data)
                data = np.pad(data, (0, int(padding)), 'constant')
            audio_data.append(data)
    return np.array(audio_data)


audio_data = load_and_preprocess_audio(directory=directory, sr=optimal_sr)

# %%
def reshape_data(data, time_steps=10):
    reshaped_data = np.array([data[i:i+time_steps] for i in range(len(data) - time_steps)])
    return reshaped_data.reshape(reshaped_data.shape[0], time_steps, -1)

time_steps = 10 
reshaped_audio_data = reshape_data(audio_data, time_steps)

# %%
def build_model(input_shape):
    model = Sequential([
        # Encoder Start
        LSTM(32, input_shape=input_shape, return_sequences=True), # returns sequences for the next layer (Uncompressed) 128
        LSTM(16, return_sequences=False), #  No return sequences (compressed) 64
        # Encoder End

        RepeatVector(input_shape[0]), # Bottleneck

        # Decoder Start
        LSTM(16, return_sequences=True), # returns sequences 64
        LSTM(32, return_sequences=True), #  returns sequences 128
        TimeDistributed(Dense(input_shape[1])) # Reconstructs the original time series data
        # Decoder End
    ])
    model.compile(optimizer='adam', loss='mse') # Compiles the model using Adam optimizer and MSE loss function
    return model


model = build_model(input_shape=reshaped_audio_data.shape[1:])
# Out:
# 2023-12-18 10:25:55.838316: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-18 10:25:55.838658: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
def train_model(model, data, epochs=50, batch_size=64):
    model.fit(data, data, epochs=epochs, batch_size=batch_size)

train_model(model, reshaped_audio_data)
# Out:
# Epoch 1/50
# 2023-12-18 10:26:24.245349: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (mklcpu) ran out of memory trying to allocate 504.49MiB (rounded to 528998400)requested by op GatherV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-12-18 10:26:24.245610: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for mklcpu
# 2023-12-18 10:26:24.245622: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245624: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245626: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245628: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245630: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245632: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245634: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245636: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245638: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245639: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245641: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245643: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245644: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245646: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245648: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245652: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 30.27MiB allocated for chunks. 30.27MiB in use in bin. 30.27MiB client-requested in use in bin.
# 2023-12-18 10:26:24.245654: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245656: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245659: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 110.99MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245661: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 252.01MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:24.245699: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 27, Chunks in use: 24. 14.96GiB allocated for chunks. 13.60GiB in use in bin. 13.60GiB client-requested in use in bin.
# 2023-12-18 10:26:24.245702: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 504.49MiB was 256.00MiB, Chunk State:
# 2023-12-18 10:26:24.245706: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 433.62MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 322.88MiB | Requested Size: 322.88MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:24.245709: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 461.49MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 504.49MiB | Requested Size: 504.49MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:24.245712: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 504.02MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 504.49MiB | Requested Size: 504.49MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:24.245714: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 7889887232
# 2023-12-18 10:26:24.245717: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 701ff5b9d040 of size 528998400 next 18
# 2023-12-18 10:26:24.245719: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70201541b040 of size 528998400 next 19
# 2023-12-18 10:26:24.245720: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702034c99040 of size 528998400 next 20
# 2023-12-18 10:26:24.245721: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702054517040 of size 528998400 next 21
# 2023-12-18 10:26:24.245723: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702073d95040 of size 528998400 next 22
# 2023-12-18 10:26:24.245724: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702093613040 of size 528998400 next 23
# 2023-12-18 10:26:24.245726: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020b2e91040 of size 528998400 next 24
# 2023-12-18 10:26:24.245727: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020d270f040 of size 528998400 next 25
# 2023-12-18 10:26:24.245728: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020f1f8d040 of size 528998400 next 26
# 2023-12-18 10:26:24.245730: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70211180b040 of size 528998400 next 27
# 2023-12-18 10:26:24.245731: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702131089040 of size 528998400 next 28
# 2023-12-18 10:26:24.245732: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702150907040 of size 528998400 next 29
# 2023-12-18 10:26:24.245734: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702170185040 of size 528998400 next 30
# 2023-12-18 10:26:24.245735: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70218fa03040 of size 528998400 next 31
# 2023-12-18 10:26:24.245737: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7021af281040 of size 483909632 next 18446744073709551615
# 2023-12-18 10:26:24.245738: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 4294967296
# 2023-12-18 10:26:24.245740: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70223fffb040 of size 1354235904 next 5
# 2023-12-18 10:26:24.245741: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702290b7b040 of size 1354235904 next 10
# 2023-12-18 10:26:24.245743: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7022e16fb040 of size 528998400 next 15
# 2023-12-18 10:26:24.245746: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702300f79040 of size 528998400 next 16
# 2023-12-18 10:26:24.245748: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023207f7040 of size 528498688 next 18446744073709551615
# 2023-12-18 10:26:24.245750: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2023-12-18 10:26:24.245751: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702343ffd040 of size 10579968 next 1
# 2023-12-18 10:26:24.245753: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702344a14040 of size 528998400 next 7
# 2023-12-18 10:26:24.245754: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702364292040 of size 10579968 next 13
# 2023-12-18 10:26:24.245755: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702364ca9040 of size 10579968 next 14
# 2023-12-18 10:26:24.245757: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023656c0040 of size 116379648 next 3
# 2023-12-18 10:26:24.245758: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70236c5bd040 of size 338558976 next 6
# 2023-12-18 10:26:24.245760: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70238089d040 of size 528998400 next 8
# 2023-12-18 10:26:24.245761: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7023a011b040 of size 338558976 next 11
# 2023-12-18 10:26:24.245762: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023b43fb040 of size 264249344 next 18446744073709551615
# 2023-12-18 10:26:24.245764: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2023-12-18 10:26:24.245765: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7023c7fff040 of size 1354235904 next 9
# 2023-12-18 10:26:24.245767: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702418b7f040 of size 338558976 next 12
# 2023-12-18 10:26:24.245768: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 70242ce5f040 of size 454688768 next 18446744073709551615
# 2023-12-18 10:26:24.245770: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-12-18 10:26:24.245772: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 10579968 totalling 30.27MiB
# 2023-12-18 10:26:24.245774: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 338558976 totalling 968.62MiB
# 2023-12-18 10:26:24.245776: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 528998400 totalling 8.87GiB
# 2023-12-18 10:26:24.245778: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1354235904 totalling 3.78GiB
# 2023-12-18 10:26:24.245783: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 13.63GiB
# 2023-12-18 10:26:24.245787: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 16479821824 memory_limit_: 16479821824 available bytes: 0 curr_region_allocation_bytes_: 17179869184
# 2023-12-18 10:26:24.246099: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     16479821824
# InUse:                     14632095744
# MaxInUse:                  14632095744
# NumAllocs:                          31
# MaxAllocSize:               1354235904
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-18 10:26:24.246103: W tensorflow/tsl/framework/bfc_allocator.cc:497] *********************************************__************************__*************************__
# 2023-12-18 10:26:24.248165: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at gather_op.cc:158 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[5,10,2644992] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 2023-12-18 10:26:34.246463: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (mklcpu) ran out of memory trying to allocate 504.49MiB (rounded to 528998400)requested by op GatherV2_1
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-12-18 10:26:34.246502: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for mklcpu
# 2023-12-18 10:26:34.246515: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246523: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246530: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246535: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246540: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246545: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246550: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246555: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246563: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246568: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246573: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246578: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246584: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246589: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246593: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246604: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 30.27MiB allocated for chunks. 30.27MiB in use in bin. 30.27MiB client-requested in use in bin.
# 2023-12-18 10:26:34.246610: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246615: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246623: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 110.99MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246629: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 252.01MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:34.246639: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks:
I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 70242ce5f040 of size 454688768 next 18446744073709551615
# 2023-12-18 10:26:34.246880: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-12-18 10:26:34.246892: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 10579968 totalling 30.27MiB
# 2023-12-18 10:26:34.246900: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 338558976 totalling 968.62MiB
# 2023-12-18 10:26:34.246906: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 528998400 totalling 8.87GiB
# 2023-12-18 10:26:34.246911: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1354235904 totalling 3.78GiB
# 2023-12-18 10:26:34.246917: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 13.63GiB
# 2023-12-18 10:26:34.246922: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 16479821824 memory_limit_: 16479821824 available bytes: 0 curr_region_allocation_bytes_: 17179869184
# 2023-12-18 10:26:34.246938: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     16479821824
# InUse:                     14632095744
# MaxInUse:                  14632095744
# NumAllocs:                          31
# MaxAllocSize:               1354235904
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-18 10:26:34.246964: W tensorflow/tsl/framework/bfc_allocator.cc:497] *********************************************__************************__*************************__
# 2023-12-18 10:26:34.247075: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at gather_op.cc:158 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[5,10,2644992] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 2023-12-18 10:26:44.267150: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (mklcpu) ran out of memory trying to allocate 504.49MiB (rounded to 528998400)requested by op GatherV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-12-18 10:26:44.267244: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for mklcpu
# 2023-12-18 10:26:44.267280: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267304: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267325: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267343: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267359: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267376: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267394: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267415: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267432: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267452: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267471: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267487: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267504: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267522: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267544: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267576: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 30.27MiB allocated for chunks. 30.27MiB in use in bin. 30.27MiB client-requested in use in bin.
# 2023-12-18 10:26:44.267597: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267615: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267637: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 110.99MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267657: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 252.01MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:44.267679: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 27, Chunks in use: 24. 14.96GiB allocated for chunks. 13.60GiB in use in bin. 13.60GiB client-requested in use in bin.
# 2023-12-18 10:26:44.267705: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 504.49MiB was 256.00MiB, Chunk State:
# 2023-12-18 10:26:44.267735: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 433.62MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 322.88MiB | Requested Size: 322.88MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:44.267762: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 461.49MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 504.49MiB | Requested Size: 504.49MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:44.267783: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 504.02MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 504.49MiB | Requested Size: 504.49MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:44.267799: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 7889887232
# 2023-12-18 10:26:44.267820: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 701ff5b9d040 of size 528998400 next 18
# 2023-12-18 10:26:44.267836: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70201541b040 of size 528998400 next 19
# 2023-12-18 10:26:44.267858: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702034c99040 of size 528998400 next 20
# 2023-12-18 10:26:44.267872: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702054517040 of size 528998400 next 21
# 2023-12-18 10:26:44.267886: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702073d95040 of size 528998400 next 22
# 2023-12-18 10:26:44.267906: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702093613040 of size 528998400 next 23
# 2023-12-18 10:26:44.267920: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020b2e91040 of size 528998400 next 24
# 2023-12-18 10:26:44.267936: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 
: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[5,10,2644992] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 2023-12-18 10:26:54.269348: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (mklcpu) ran out of memory trying to allocate 504.49MiB (rounded to 528998400)requested by op GatherV2_1
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-12-18 10:26:54.269430: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for mklcpu
# 2023-12-18 10:26:54.269460: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269479: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269494: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269510: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269528: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269546: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269563: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269580: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269594: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269610: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269626: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269641: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269657: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269671: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269686: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269716: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 30.27MiB allocated for chunks. 30.27MiB in use in bin. 30.27MiB client-requested in use in bin.
# 2023-12-18 10:26:54.269734: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269752: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269775: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 110.99MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.269977: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 252.01MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-18 10:26:54.270001: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 27, Chunks in use: 24. 14.96GiB allocated for chunks. 13.60GiB in use in bin. 13.60GiB client-requested in use in bin.
# 2023-12-18 10:26:54.270023: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 504.49MiB was 256.00MiB, Chunk State:
# 2023-12-18 10:26:54.270044: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 433.62MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 322.88MiB | Requested Size: 322.88MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:54.270059: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 461.49MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 504.49MiB | Requested Size: 504.49MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:54.270073: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 504.02MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 504.49MiB | Requested Size: 504.49MiB | in_use: 1 | bin_num: -1
# 2023-12-18 10:26:54.270088: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 7889887232
# 2023-12-18 10:26:54.270106: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 701ff5b9d040 of size 528998400 next 18
# 2023-12-18 10:26:54.270115: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70201541b040 of size 528998400 next 19
# 2023-12-18 10:26:54.270124: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702034c99040 of size 528998400 next 20
# 2023-12-18 10:26:54.270132: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702054517040 of size 528998400 next 21
# 2023-12-18 10:26:54.270151: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702073d95040 of size 528998400 next 22
# 2023-12-18 10:26:54.270160: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702093613040 of size 528998400 next 23
# 2023-12-18 10:26:54.270168: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020b2e91040 of size 528998400 next 24
# 2023-12-18 10:26:54.270176: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020d270f040 of size 528998400 next 25
# 2023-12-18 10:26:54.270185: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7020f1f8d040 of size 528998400 next 26
# 2023-12-18 10:26:54.270193: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70211180b040 of size 528998400 next 27
# 2023-12-18 10:26:54.270201: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702131089040 of size 528998400 next 28
# 2023-12-18 10:26:54.270209: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702150907040 of size 528998400 next 29
# 2023-12-18 10:26:54.270218: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702170185040 of size 528998400 next 30
# 2023-12-18 10:26:54.270226: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70218fa03040 of size 528998400 next 31
# 2023-12-18 10:26:54.270235: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7021af281040 of size 483909632 next 18446744073709551615
# 2023-12-18 10:26:54.270244: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 4294967296
# 2023-12-18 10:26:54.270254: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70223fffb040 of size 1354235904 next 5
# 2023-12-18 10:26:54.270263: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702290b7b040 of size 1354235904 next 10
# 2023-12-18 10:26:54.270271: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7022e16fb040 of size 528998400 next 15
# 2023-12-18 10:26:54.270279: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702300f79040 of size 528998400 next 16
# 2023-12-18 10:26:54.270288: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023207f7040 of size 528498688 next 18446744073709551615
# 2023-12-18 10:26:54.270297: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2023-12-18 10:26:54.270309: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702343ffd040 of size 10579968 next 1
# 2023-12-18 10:26:54.270318: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702344a14040 of size 528998400 next 7
# 2023-12-18 10:26:54.270327: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702364292040 of size 10579968 next 13
# 2023-12-18 10:26:54.270338: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702364ca9040 of size 10579968 next 14
# 2023-12-18 10:26:54.270352: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023656c0040 of size 116379648 next 3
# 2023-12-18 10:26:54.270366: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70236c5bd040 of size 338558976 next 6
# 2023-12-18 10:26:54.270380: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70238089d040 of size 528998400 next 8
# 2023-12-18 10:26:54.270395: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7023a011b040 of size 338558976 next 11
# 2023-12-18 10:26:54.270409: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023b43fb040 of size 264249344 next 18446744073709551615
# 2023-12-18 10:26:54.270422: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2023-12-18 10:26:54.270437: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7023c7fff040 of size 1354235904 next 9
# 2023-12-18 10:26:54.270452: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702418b7f040 of size 338558976 next 12
# 2023-12-18 10:26:54.270466: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 70242ce5f040 of size 454688768 next 18446744073709551615
# 2023-12-18 10:26:54.270480: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-12-18 10:26:54.270501: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 10579968 totalling 30.27MiB
# 2023-12-18 10:26:54.270521: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 338558976 totalling 968.62MiB
# 2023-12-18 10:26:54.270540: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 528998400 totalling 8.87GiB
# 2023-12-18 10:26:54.270557: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1354235904 totalling 3.78GiB
# 2023-12-18 10:26:54.270580: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 13.63GiB
# 2023-12-18 10:26:54.270597: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 16479821824 memory_limit_: 16479821824 available bytes: 0 curr_region_allocation_bytes_: 17179869184
# 2023-12-18 10:26:54.270625: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     16479821824
# InUse:                     14632095744
# MaxInUse:                  14632095744
# NumAllocs:                          31
# MaxAllocSize:               1354235904
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-18 10:26:54.270649: W tensorflow/tsl/framework/bfc_allocator.cc:497] *********************************************__************************__*************************__
# 2023-12-18 10:26:54.270715: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at gather_op.cc:158 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[5,10,2644992] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# ...
# 2023-12-18 10:28:54.291255: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-12-18 10:28:54.291265: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 10579968 totalling 30.27MiB
# 2023-12-18 10:28:54.291275: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 338558976 totalling 968.62MiB
# 2023-12-18 10:28:54.291285: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 528998400 totalling 8.87GiB
# 2023-12-18 10:28:54.291294: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1354235904 totalling 3.78GiB
# 2023-12-18 10:28:54.291303: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 13.63GiB
# 2023-12-18 10:28:54.291312: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 16479821824 memory_limit_: 16479821824 available bytes: 0 curr_region_allocation_bytes_: 17179869184
# 2023-12-18 10:28:54.291326: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     16479821824
# InUse:                     14632095744
# MaxInUse:                  14632095744
# NumAllocs:                          31
# MaxAllocSize:               1354235904
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-18 10:28:54.291337: W tensorflow/tsl/framework/bfc_allocator.cc:497] *********************************************__************************__*************************__
# 2023-12-18 10:28:54.291371: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at gather_op.cc:158 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape
I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023207f7040 of size 528498688 next 18446744073709551615
# 2023-12-18 10:29:04.428414: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2023-12-18 10:29:04.428429: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702343ffd040 of size 10579968 next 1
# 2023-12-18 10:29:04.428470: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702344a14040 of size 528998400 next 7
# 2023-12-18 10:29:04.428485: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702364292040 of size 10579968 next 13
# 2023-12-18 10:29:04.428498: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702364ca9040 of size 10579968 next 14
# 2023-12-18 10:29:04.428511: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023656c0040 of size 116379648 next 3
# 2023-12-18 10:29:04.428520: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70236c5bd040 of size 338558976 next 6
# 2023-12-18 10:29:04.428529: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 70238089d040 of size 528998400 next 8
# 2023-12-18 10:29:04.428537: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7023a011b040 of size 338558976 next 11
# 2023-12-18 10:29:04.428546: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7023b43fb040 of size 264249344 next 18446744073709551615
# 2023-12-18 10:29:04.428554: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2147483648
# 2023-12-18 10:29:04.428563: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7023c7fff040 of size 1354235904 next 9
# 2023-12-18 10:29:04.428572: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 702418b7f040 of size 338558976 next 12
# 2023-12-18 10:29:04.428580: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 70242ce5f040 of size 454688768 next 18446744073709551615
# 2023-12-18 10:29:04.428589: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-12-18 10:29:04.428603: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 10579968 totalling 30.27MiB
# 2023-12-18 10:29:04.428614: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 338558976 totalling 968.62MiB
# 2023-12-18 10:29:04.428625: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 528998400 totalling 8.87GiB
# 2023-12-18 10:29:04.428636: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1354235904 totalling 3.78GiB
# 2023-12-18 10:29:04.428646: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 13.63GiB
# 2023-12-18 10:29:04.428656: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 16479821824 memory_limit_: 16479821824 available bytes: 0 curr_region_allocation_bytes_: 17179869184
# 2023-12-18 10:29:04.428675: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     16479821824
# InUse:                     14632095744
# MaxInUse:                  14632095744
# NumAllocs:                          31
# MaxAllocSize:               1354235904
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-18 10:29:04.428690: W tensorflow/tsl/framework/bfc_allocator.cc:497] *********************************************__************************__*************************__
# 2023-12-18 10:29:04.438450: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at transpose_op.cc:184 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[10,5,2644992] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[11], line 4
#       1 def train_model(model, data, epochs=50, batch_size=64):
#       2     model.fit(data, data, epochs=epochs, batch_size=batch_size)
# ----> 4 train_model(model, reshaped_audio_data)
#
# Cell In[11], line 2, in train_model(model, data, epochs, batch_size)
#       1 def train_model(model, data, epochs=50, batch_size=64):
# ----> 2     model.fit(data, data, epochs=epochs, batch_size=batch_size)
#
# File ~/miniconda3/envs/audio_class/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/audio_class/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# OOM when allocating tensor with shape[10,5,2644992] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 	 [[{{node transpose_0}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[sequential/lstm/PartitionedCall]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_11268]

# %%
def detect_anomalies(model, data, threshold=0.1):
    predictions = model.predict(data)
    anomalies = []
    for i in range(len(data)):
        loss = np.mean(np.abs(data[i] - predictions[i]))
        if loss > threshold:
            anomalies.append(i)
    return anomalies

# anomalies = detect_anomalies(model, reshaped_audio_data)
# print("Anomalies found at indices:", anomalies)
